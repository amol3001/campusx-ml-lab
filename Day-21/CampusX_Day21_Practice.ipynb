# %% [markdown]
# # 📊 CampusX 100 Days of ML — Day 21
# ## EDA: Bivariate & Multivariate Analysis — Practice Notebook
# **Amol Jagtap | amoljagtap3001@gmail.com**
#
# ---
#
# ### How to use this notebook
# - Read each exercise carefully
# - Write your code in the `# YOUR CODE HERE` cell below each question
# - Run the cell and check the output
# - Do **not** look at the Answer Notebook until you have tried each exercise
#
# ### Topics
# | Section | Topic |
# |---------|-------|
# | 1 | Setup & Dataset Exploration |
# | 2 | Numerical vs Numerical |
# | 3 | Numerical vs Categorical |
# | 4 | Categorical vs Categorical |
# | 5 | Multivariate Analysis |
# | 6 | Full EDA Challenge |

# %% [markdown]
# ---
# ## ⚙️ Setup — Run This Cell First

# %%
# Amol Jagtap | amoljagtap3001@gmail.com
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load datasets
tips    = sns.load_dataset('tips')
iris    = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')

# Set a clean theme
sns.set_theme(style='whitegrid')

print('Tips shape   :', tips.shape)
print('Iris shape   :', iris.shape)
print('Titanic shape:', titanic.shape)
print(tips.head())

# %% [markdown]
# ---
# ## 📁 Section 1: Dataset Exploration
# > Before plotting, always understand your data.

# %% [markdown]
# ### Exercise 1.1 — Data Overview
# Using the `tips` dataset:
# 1. Print the first 5 rows
# 2. Print the shape (rows × columns)
# 3. Print the data types of each column
# 4. List which columns are **numerical** and which are **categorical**

# %%
# 1. First 5 rows


# 2. Shape


# 3. Data types


# 4. Separate numerical and categorical columns
numerical   = # YOUR CODE HERE
categorical = # YOUR CODE HERE
print('Numerical  :', numerical)
print('Categorical:', categorical)

# %% [markdown]
# ### Exercise 1.2 — Missing Values Check
# 1. Check for missing values in the `tips` dataset
# 2. Check for missing values in the `titanic` dataset
# 3. For `titanic`, which column has the most missing values?

# %%
# Missing values in tips


# Missing values in titanic


# Column with most missing values in titanic

# %% [markdown]
# ### Exercise 1.3 — Basic Stats
# 1. Print the statistical summary of `tips` numerical columns
# 2. What is the mean tip?
# 3. What is the maximum total_bill?

# %%
# Statistical summary


# Mean tip


# Maximum total_bill

# %% [markdown]
# ---
# ## 📈 Section 2: Numerical vs Numerical

# %% [markdown]
# ### Exercise 2.1 — Scatter Plot (Basic)
# Plot `total_bill` (X-axis) vs `tip` (Y-axis) from the `tips` dataset.
# - Add a descriptive title
# - Label both axes

# %%
plt.figure(figsize=(7, 5))
# YOUR CODE HERE

plt.show()

# %% [markdown]
# ### Exercise 2.2 — Scatter Plot with Hue and Style
# Plot `total_bill` vs `tip` and:
# - Colour by `sex`
# - Change marker shape by `smoker`
# - Scale marker size by `size`
#
# What do you observe about male vs female tipping?

# %%
plt.figure(figsize=(8, 6))
# YOUR CODE HERE

plt.show()

# Your observation (write as a comment):
#

# %% [markdown]
# ### Exercise 2.3 — Correlation Coefficient
# 1. Find the Pearson correlation between `total_bill` and `tip`
# 2. Find the Pearson correlation between `total_bill` and `size`
# 3. Print the full correlation matrix for all numeric columns
# 4. Which two columns have the highest correlation?

# %%
# 1. total_bill vs tip


# 2. total_bill vs size


# 3. Full correlation matrix


# 4. Highest correlation pair
# Answer:

# %% [markdown]
# ### Exercise 2.4 — Correlation Heatmap
# Draw a heatmap of the correlation matrix for tips numerical columns.
# - Use `annot=True` to show values inside cells
# - Use `cmap='Blues'`
# - Set `vmin=-1, vmax=1` to fix the scale
# - Add a title

# %%
plt.figure(figsize=(6, 4))
# YOUR CODE HERE

plt.show()

# %% [markdown]
# ### Exercise 2.5 — Pair Plot
# 1. Create a pair plot of the `iris` dataset coloured by `species`
# 2. Use `diag_kind='kde'` for the diagonal
# 3. Write one observation about the relationship between
#    `petal_length` and `petal_width`

# %%
# YOUR CODE HERE

plt.show()

# Observation:
#

# %% [markdown]
# ---
# ## 📦 Section 3: Numerical vs Categorical

# %% [markdown]
# ### Exercise 3.1 — Bar Plot (Mean)
# 1. Plot the average `total_bill` for each `day`
# 2. Then plot the average `total_bill` for each `day`, coloured by `sex`
# 3. On which day is the average bill the highest?

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Left: average total_bill per day
# YOUR CODE HERE


# Right: grouped by sex
# YOUR CODE HERE


plt.tight_layout()
plt.show()

# Highest bill day:
#

# %% [markdown]
# ### Exercise 3.2 — Box Plot
# 1. Draw a box plot of `total_bill` for each `day`
# 2. Add `hue='sex'` to compare males and females
# 3. On which day do males have higher median bills than females?
# 4. Which group has the most outliers?

# %%
plt.figure(figsize=(9, 5))
# YOUR CODE HERE

plt.show()

# Your answers:
# 3. 
# 4.

# %% [markdown]
# ### Exercise 3.3 — Violin Plot
# Create a violin plot of `tip` by `day`:
# - Split by `sex` using `split=True`
# - Figure size: (10, 5)
# - Add a title
#
# What can you see that a box plot would hide?

# %%
plt.figure(figsize=(10, 5))
# YOUR CODE HERE

plt.show()

# Observation:
#

# %% [markdown]
# ### Exercise 3.4 — Strip Plot Overlay
# Combine a violin plot with a strip plot:
# 1. Draw `violinplot` of `total_bill` by `day` (inner=None, muted colours)
# 2. Overlay `stripplot` on the same axes (small dark points)
#
# Hint: pass `ax=ax` to both calls after creating `fig, ax = plt.subplots()`

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# Step 1: violin (use inner=None so it looks clean underneath)
# YOUR CODE HERE


# Step 2: overlay strip plot
# YOUR CODE HERE


ax.set_title('Violin + Strip: total_bill by day')
plt.show()

# %% [markdown]
# ---
# ## 🔢 Section 4: Categorical vs Categorical

# %% [markdown]
# ### Exercise 4.1 — Cross-Tabulation
# 1. Create a cross-tab of `sex` vs `day` in the `tips` dataset
# 2. Create a **normalised** cross-tab (rows sum to 1)
# 3. On which day did females make up the highest proportion of diners?

# %%
# 1. Raw counts


# 2. Normalised (rows sum to 1)


# 3. Highest female proportion day:
#

# %% [markdown]
# ### Exercise 4.2 — Cross-Tab with Values
# Create a cross-tab showing the **mean tip** for each `sex` × `day` combination.
#
# Hint: use `values=` and `aggfunc=` parameters of `pd.crosstab`

# %%
# Mean tip per sex × day
# YOUR CODE HERE

# %% [markdown]
# ### Exercise 4.3 — Grouped Bar Chart
# 1. Draw a count plot showing number of diners per `day`, grouped by `sex`
# 2. Draw a **stacked** bar chart of the same data using `pd.crosstab` + `.plot()`

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Left: countplot
# YOUR CODE HERE


# Right: stacked bar
ct = pd.crosstab(tips['day'], tips['sex'])
# YOUR CODE HERE


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 4.4 — Categorical Heatmap
# Visualise the cross-tab of `sex` vs `smoker` as a **heatmap**:
# - Annotate with counts
# - Use `fmt='d'` (integer format)
# - Use `cmap='YlOrRd'`

# %%
plt.figure(figsize=(5, 3))
# Step 1: create cross-tab


# Step 2: plot heatmap
# YOUR CODE HERE


plt.title('Count: sex vs smoker')
plt.show()

# %% [markdown]
# ---
# ## 🌐 Section 5: Multivariate Analysis

# %% [markdown]
# ### Exercise 5.1 — 4-Variable Scatter
# Create one scatter plot that encodes **4 variables** at once:
# - X = `total_bill`
# - Y = `tip`
# - Colour (hue) = `sex`
# - Marker shape (style) = `smoker`
# - Marker size = `size`

# %%
plt.figure(figsize=(9, 6))
# YOUR CODE HERE

plt.title('4-Variable Scatter: total_bill vs tip')
plt.show()

# %% [markdown]
# ### Exercise 5.2 — FacetGrid
# Create a FacetGrid showing the distribution of `total_bill`:
# - `col = 'time'`  (Lunch | Dinner)
# - `row = 'sex'`   (Male | Female)
# - Inside each cell: histogram of `total_bill` with 15 bins

# %%
# Step 1: create FacetGrid
g = sns.FacetGrid(
    tips,
    col='time',
    row='sex',
    height=3,
    aspect=1.2
)

# Step 2: map histogram to each cell
# YOUR CODE HERE


plt.show()

# %% [markdown]
# ### Exercise 5.3 — Full Pair Plot with Hue
# Using the `iris` dataset:
# 1. Create a pair plot coloured by `species`
# 2. Use only `petal_length` and `petal_width` as variables
# 3. Set `diag_kind='hist'`
# 4. Write which species is most easily separated.

# %%
# YOUR CODE HERE

plt.show()

# Most separable species:
#

# %% [markdown]
# ### Exercise 5.4 — Multivariate Heatmap (Titanic)
# 1. Select numeric columns from `titanic` (drop NaN rows first)
# 2. Compute the correlation matrix
# 3. Draw a heatmap with:
#    - `annot=True`
#    - `cmap='coolwarm'`
#    - Mask the upper triangle (show only lower triangle)

# %%
import numpy as np

# Step 1: numeric columns only
t_num = titanic.select_dtypes(include='number').dropna()

# Step 2: correlation matrix


# Step 3: create upper-triangle mask
mask = np.triu(np.ones_like(corr, dtype=bool))

# Step 4: heatmap
plt.figure(figsize=(8, 6))
# YOUR CODE HERE

plt.title('Titanic Correlation Heatmap (Lower Triangle)')
plt.show()

# %% [markdown]
# ---
# ## 🏆 Section 6: Full EDA Challenge — Titanic Dataset
#
# You are a data scientist at a shipping company.
# Use bivariate and multivariate analysis to answer the following
# questions about the Titanic passenger data.
#
# **Answer each question with a plot AND a one-sentence observation.**

# %% [markdown]
# ### Challenge Q1 — Did fare affect survival?
# Plot the distribution of `fare` split by `survived` (0 = No, 1 = Yes).
# Use a box plot. What do you notice?

# %%
plt.figure(figsize=(7, 5))
# YOUR CODE HERE

plt.show()

# Observation:
#

# %% [markdown]
# ### Challenge Q2 — Did passenger class affect survival?
# Create a **grouped bar chart** showing survival rate per `pclass`.
# Hint: use `sns.barplot` with `y='survived'`.

# %%
plt.figure(figsize=(6, 4))
# YOUR CODE HERE

plt.show()

# Observation:
#

# %% [markdown]
# ### Challenge Q3 — Did sex affect survival?
# Create a cross-tabulation of `sex` vs `survived` and also plot it as a heatmap.

# %%
# Cross-tab


# Heatmap
plt.figure(figsize=(5, 3))
# YOUR CODE HERE

plt.show()

# Observation:
#

# %% [markdown]
# ### Challenge Q4 — Age vs Fare scatter
# Create a scatter plot of `age` vs `fare`:
# - Colour by `survived`
# - Style by `sex`
# - Add alpha=0.6 so overlapping dots are visible

# %%
t_clean = titanic.dropna(subset=['age', 'fare'])

plt.figure(figsize=(9, 6))
# YOUR CODE HERE

plt.show()

# Observation:
#

# %% [markdown]
# ### Challenge Q5 — Mini Dashboard (2 × 2)
# Create a 2×2 subplot dashboard answering these four questions:
# 1. Top-left: Age distribution by survived (box plot)
# 2. Top-right: Fare by pclass (violin plot)
# 3. Bottom-left: Survival count by sex (count plot)
# 4. Bottom-right: Correlation heatmap of numeric columns

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Top-left: age by survived
# YOUR CODE HERE


# Top-right: fare by pclass
# YOUR CODE HERE


# Bottom-left: survival count by sex
# YOUR CODE HERE


# Bottom-right: correlation heatmap
t_n = titanic.select_dtypes(include='number').dropna()
# YOUR CODE HERE


plt.suptitle('Titanic EDA Dashboard — Day 21', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig('/mnt/user-data/outputs/campusx_day21/titanic_dashboard.png',
            dpi=150, bbox_inches='tight')
plt.show()
