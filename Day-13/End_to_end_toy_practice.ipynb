# %% [markdown]
# # Day 13 Practice Notebook: End-to-End Machine Learning Toy Project
#
# ## 1. Introduction & Project Architecture
# This practice workbook is designed for you to replicate the complete 8-step Machine Learning pipeline covered in Day 13. Your goal is to build a classification model to predict student placement based on **CGPA** and **IQ**.
#
# ### Instructions:
# - Fill in the empty code cells below each prompt to build your workflow.
# - Ensure your dataset `placement.csv` is uploaded to your environment before running.

# %% [markdown]
# ## 2. Environment Setup & Data Ingestion
# **Instruction:** Import `numpy`, `pandas`, and `matplotlib.pyplot`. Then, read the `placement.csv` file into a dataframe named `df` and display its shape and the first five rows.

# %%
# TODO: Import libraries


# TODO: Load the dataset and print shape


# TODO: Display the first 5 rows

# %% [markdown]
# ## 3. Data Preprocessing
# **Instruction:** Check the dataset information summary using `.info()`. Notice the unnecessary named structural or index column, then slice the dataframe using `.iloc` to completely remove it.

# %%
# TODO: Check data info for missing values and column types


# TODO: Drop the redundant first column using slicing


# TODO: Verify the changes by printing df.head()

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)
# **Instruction:** Create a scatter plot mapping `cgpa` on the X-axis and `iq` on the Y-axis. Color the data points dynamically based on the target column `placement` to observe the decision boundary structure.

# %%
# TODO: Plot a scatter plot using matplotlib


# TODO: Set appropriate labels for X-axis, Y-axis, and Title

# %% [markdown]
# ## 5. Feature Selection (Splitting Input and Output Matrices)
# **Instruction:** Isolate your independent feature columns (`cgpa`, `iq`) into a variable named `X`, and assign the target prediction label (`placement`) to a variable named `y`.

# %%
# TODO: Extract feature matrix X


# TODO: Extract target vector y


# TODO: Print shapes of X and y to confirm layout

# %% [markdown]
# ## 6. Train-Test Split
# **Instruction:** Import `train_test_split` from sklearn. Segment the data matrix into a 90% training split and a 10% testing split. Use a `random_state` parameter to keep your splits reproducible.

# %%
# TODO: Import train_test_split


# TODO: Perform the split operation into X_train, X_test, y_train, y_test

# %% [markdown]
# ## 7. Feature Scaling
# **Instruction:** Import `StandardScaler` from sklearn. Instantiate an object of the scaler, fit and transform the training array (`X_train`), then scale the testing array (`X_test`) using those same calculated parameters.

# %%
# TODO: Import StandardScaler


# TODO: Fit and transform X_train


# TODO: Transform X_test

# %% [markdown]
# ## 8. Model Training & Evaluation
# **Instruction:** Import `LogisticRegression` and `accuracy_score` from sklearn. Instantiate the classifier model, fit it using your scaled training data, run predictions on `X_test`, and print out the computed accuracy percentage score.

# %%
# TODO: Import LogisticRegression and evaluation metrics


# TODO: Initialize model and fit onto training data


# TODO: Generate predictions against X_test


# TODO: Calculate and display the final accuracy score percentage

# %% [markdown]
# ### Plotting Decision Boundary (Optional Verification)
# **Instruction:** If you have the `mlxtend` package installed, import `plot_decision_regions` and use it to visually graph the linear classification boundary generated by your trained model instance.

# %%
# TODO: Plot decision boundary using mlxtend toolset

# %% [markdown]
# ## 9. Model Serialization for Deployment
# **Instruction:** Import Python's built-in `pickle` module. Export your trained classifier model object to a local binary file named `model.pkl` so that it can be loaded later in your web applications.

# %%
# TODO: Import pickle


# TODO: Open file 'model.pkl' in write-binary mode and dump the model
