# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('max_abs.csv')

# %%
train = df[['Age','Salary','Experience']]

# %%
test = df['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(train,test,test_size=0.2,random_state=0)

# %%
df.shape
# Out:
# (500, 4)

# %%
X_train.shape
# Out:
# (400, 3)

# %%
X_test.shape
# Out:
# (100, 3)

# %%
y_test.shape
# Out:
# (100,)

# %%
y_train.shape
# Out:
# (400,)

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scaler = MaxAbsScaler()

# %%
scaler.fit(X_train,X_test)
# Out:
# MaxAbsScaler()

# %%
X_train_scaled = scaler.transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled.shape
# Out:
# (400, 3)

# %%
X_train_scaled.describe()
# Out:
#               Age      Salary  Experience
# count  400.000000  400.000000  400.000000
# mean     0.655042    0.552325    0.442250
# std      0.207866    0.269216    0.298076
# min      0.300000    0.101684    0.000000
# 25%      0.479167    0.312040    0.168750
# 50%      0.683333    0.559375    0.475000
# 75%      0.833333    0.788171    0.675000
# max      1.000000    1.000000    1.000000

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn_scaled = KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
knn_scaled.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
pred = knn.predict(X_test)

# %%
pred_scaled = knn_scaled.predict(X_test_scaled)

# %%
print('Normal:',accuracy_score(y_test,pred))
print('Scaled',accuracy_score(y_test,pred_scaled))
# Out:
# Normal: 0.56
# Scaled 0.98
